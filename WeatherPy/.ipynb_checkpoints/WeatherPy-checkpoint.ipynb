# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kristinestad
# Processing Record 2 of Set 1 | metro
# Processing Record 3 of Set 1 | alta
# Processing Record 4 of Set 1 | zhigalovo
# Processing Record 5 of Set 1 | ankazobe
# Processing Record 6 of Set 1 | strezhevoy
# Processing Record 7 of Set 1 | nemuro
# Processing Record 8 of Set 1 | zheleznogorsk
# Processing Record 9 of Set 1 | urcos
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | waitangi
# Processing Record 12 of Set 1 | mantenopolis
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | afaahiti
# Processing Record 16 of Set 1 | blackmans bay
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | bozhou
# Processing Record 20 of Set 1 | margaret river
# Processing Record 21 of Set 1 | ushuaia
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  kristinestad  62.2743   21.3760    272.09        80         100
# 1         metro  -5.1131  105.3067    297.37        79          10
# 2          alta  69.9689   23.2717    267.74        82          20
# 3     zhigalovo  54.8097  105.1578    265.45        56          32
# 4      ankazobe -18.3167   47.1167    293.68        72          98
#
#    Wind Speed Country        Date
# 0        4.79      FI  1698592567
# 1        1.82      ID  1698592568
# 2        3.09      NO  1698592568
# 3        0.98      RU  1698592569
# 4        0.63      MG  1698592569

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        kristinestad  62.2743   21.3760    272.09        80         100
# 1               metro  -5.1131  105.3067    297.37        79          10
# 2                alta  69.9689   23.2717    267.74        82          20
# 3           zhigalovo  54.8097  105.1578    265.45        56          32
# 4            ankazobe -18.3167   47.1167    293.68        72          98
#
#          Wind Speed Country        Date
# City_ID
# 0              4.79      FI  1698592567
# 1              1.82      ID  1698592568
# 2              3.09      NO  1698592568
# 3              0.98      RU  1698592569
# 4              0.63      MG  1698592569

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x="Lat", y="Max Temp", grid=True, marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-10-29)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (K)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x="Lat", y="Humidity", grid=True, marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2023-10-29)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x="Lat", y="Cloudiness", grid=True, marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2023-10-29)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x="Lat", y="Wind Speed", grid=True, marker="o", facecolors="blue", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2023-10-29)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linregression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    xl,xr = plt.xlim()
    xshift = xl + 10
    yl,yr = plt.ylim()
    yshift = yl + 10
    plt.annotate(line_eq,(xshift,yshift),fontsize=15,color="red")
    print(f"The r-value is: {rvalue}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        kristinestad  62.2743   21.3760    272.09        80         100
# 2                alta  69.9689   23.2717    267.74        82          20
# 3           zhigalovo  54.8097  105.1578    265.45        56          32
# 5          strezhevoy  60.7333   77.5889    263.13        85          13
# 6              nemuro  43.3236  145.5750    283.37        74          55
#
#          Wind Speed Country        Date
# City_ID
# 0              4.79      FI  1698592567
# 2              3.09      NO  1698592568
# 3              0.98      RU  1698592569
# 5              1.34      RU  1698592570
# 6              4.40      JP  1698592570

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            metro  -5.1131  105.3067    297.37        79          10
# 4         ankazobe -18.3167   47.1167    293.68        72          98
# 8            urcos -13.6861  -71.6228    292.09        51         100
# 9        adamstown -25.0660 -130.1015    295.45        84         100
# 10        waitangi -43.9535 -176.5597    280.83        93           6
#
#          Wind Speed Country        Date
# City_ID
# 1              1.82      ID  1698592568
# 4              0.63      MG  1698592569
# 8              2.05      PE  1698592571
# 9              7.33      PN  1698592572
# 10             2.12      NZ  1698592572

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linregression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Temperature vs. Latitude in Northern Hemisphere')
plt.show()
# Out:
# The r-value is: -0.8663226014430856

# %%
# Linear regression on Southern Hemisphere
linregression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title('Temperature vs. Latitude in Southern Hemisphere')
plt.show()
# Out:
# The r-value is: 0.7483874803078598

# %% [markdown]
# **Discussion about the linear relationship:
# In the Northern Hemisphere there is a strong negative correlation between temperature and latitude.  As the latitude increases and gets further from the equator, the temperature decreases.  In the Southern Hemisphere there is an equally strong positive correlation between temperature and latitude.  As the latitude increases and gets closer to the equator, the temperature increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Humidity vs. Latitude in Northern Hemisphere')
plt.show()
# Out:
# The r-value is: 0.2799388965132307

# %%
# Southern Hemisphere
linregression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Humidity vs. Latitude in Southern Hemisphere')
plt.show()
# Out:
# The r-value is: 0.025967222638919846

# %% [markdown]
# **Discussion about the linear relationship:**
# There is a very small positive correlation between humidity and latitude in the Northern Hemisphere.  As the latitude increases and gets further from the equator the humidity increases.  There is no correlation between humidity and latitude in the Southern Hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness vs. Latitude in Northern Hemisphere')
plt.show()
# Out:
# The r-value is: 0.09106438190238891

# %%
# Southern Hemisphere
linregression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Cloudiness vs. Latitude in Southern Hemisphere')
plt.show()
# Out:
# The r-value is: 0.05135066678879613

# %% [markdown]
# **Discussion about the linear relationship:**
# There is no correlation between Cloudiness and Latitude in the Northern or Southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linregression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Wind Speed vs. Latitude in Northern Hemisphere')
plt.show()
# Out:
# The r-value is: -0.008221859826375664

# %%
# Southern Hemisphere
linregression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Wind Speed vs. Latitude in Southern Hemisphere')
plt.show()
# Out:
# The r-value is: -0.30868361210689016

# %% [markdown]
# **Discussion about the linear relationship:**
# The is no correlation between Wind Speed and Latitude in the Northern Hemisphere.  There is a very small negative correlation between Wind Speed and Latitude in the Southern Hemisphere.  As the Latitude increases and gets closer to the equator, the wind speed slightly decreases.
