# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pprint import pprint

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  kristinestad  62.2743   21.3760    272.09        80         100
# 1        1         metro  -5.1131  105.3067    297.37        79          10
# 2        2          alta  69.9689   23.2717    267.74        82          20
# 3        3     zhigalovo  54.8097  105.1578    265.45        56          32
# 4        4      ankazobe -18.3167   47.1167    293.68        72          98
#
#    Wind Speed Country        Date
# 0        4.79      FI  1698592567
# 1        1.82      ID  1698592568
# 2        3.09      NO  1698592568
# 3        0.98      RU  1698592569
# 4        0.63      MG  1698592569

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_map_humidity = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 0.75
)

# Display the map
city_map_humidity
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_city_data_df = city_data_df.loc[(city_data_df["Humidity"] <= 70)
                                      & (city_data_df["Max Temp"] <= 302)
                                      & (city_data_df["Max Temp"] >= 294)
                                      & (city_data_df["Wind Speed"] <= 3)
                                      & (city_data_df["Cloudiness"] <= 30)]

# Drop any rows with null values
ideal_city_data_df = ideal_city_data_df.dropna(how = "any")

# Display sample data
ideal_city_data_df
# Out:
#      City_ID              City      Lat      Lng  Max Temp  Humidity  \
# 29        29           tir pul  34.5943  61.2690    297.46        26
# 75        75          bhandara  21.1667  79.6500    294.58        55
# 118      118         zahir pir  28.8124  70.5240    301.22        22
# 280      280        hanceville  34.0607 -86.7675    297.83        61
# 306      306   juan de herrera  18.8740 -71.2383    300.79        70
# 350      350   santa terezinha -29.9002 -50.0904    299.15        67
# 368      368              argo  37.6333  22.7333    296.36        55
# 416      416        aurangabad  19.8833  75.3333    296.71        38
# 426      426          pipraich  26.8264  83.5300    296.23        49
# 524      524  kill devil hills  36.0307 -75.6760    296.16        61
# 541      541             sadri  25.1833  73.4333    299.07        30
# 546      546        villa rica  33.7321 -84.9191    297.27        70
#
#      Cloudiness  Wind Speed Country        Date
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_city_data_df.copy()
hotel_df = hotel_df[["City_ID", "City", "Country", "Lat", "Lng", "Humidity"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API

hotel_df["Hotel Name"] = "" 

# Display sample data
hotel_df.head()
# Out:
#      City_ID             City Country      Lat      Lng  Humidity Hotel Name
# 29        29          tir pul      AF  34.5943  61.2690        26
# 75        75         bhandara      IN  21.1667  79.6500        55
# 118      118        zahir pir      PK  28.8124  70.5240        22
# 280      280       hanceville      US  34.0607 -86.7675        61
# 306      306  juan de herrera      DO  18.8740 -71.2383        70

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 200
params = {
    "limit":limit,
    "categories":f"accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Lat = hotel_df.loc[index, "Lat"]
    Lng = hotel_df.loc[index, "Lng"]
       
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{Lng},{Lat},{radius}"
    params["bias"] = f"proximity:{Lng},{Lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make an API request using the params dictionary
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# tir pul - nearest hotel: No hotel found
# bhandara - nearest hotel: Hotel Royal Plaza
# zahir pir - nearest hotel: No hotel found
# hanceville - nearest hotel: No hotel found
# juan de herrera - nearest hotel: No hotel found
# santa terezinha - nearest hotel: Pousada Santa Terezinha
# argo - nearest hotel: Apollon Hotel
# aurangabad - nearest hotel: spice
# pipraich - nearest hotel: No hotel found
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# sadri - nearest hotel: Chandra Hill Resort
# villa rica - nearest hotel: Comfort Inn & Suites
#      City_ID              City Country      Lat      Lng  Humidity  \
# 29        29           tir pul      AF  34.5943  61.2690        26
# 75        75          bhandara      IN  21.1667  79.6500        55
# 118      118         zahir pir      PK  28.8124  70.5240        22
# 280      280        hanceville      US  34.0607 -86.7675        61
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
city_map_hotel = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 0.75,
    hover_cols = ["City", "Hotel Name", "Country"]
)

# Display the map
city_map_hotel
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Hotel Name,Country)

# %%
# %%capture --no-display
# Adding this additional map because it's hard to make out the humidity levels by dot size.  I think the color works better.
# Configure the map plot
city_map_hotel_color = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    color = "Humidity",
    scale = 0.75,
    hover_cols = ["City", "Hotel Name", "Country"]
)

# Display the map
city_map_hotel_color
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Hotel Name,Country)
